# %%
# %load_ext autoreload
import uproot as ut
import awkward as ak
import matplotlib.pyplot as plt
import numpy as np
import re
import sympy as sp
import math
import vector


from tqdm import tqdm
import timeit

from utils import *
# %autoreload 2

# %%
signal_tree = Tree( fc.sr.NMSSM_MX_700_MY_400 )
lumikey=2018

# %%
qcd_tree = Tree( fc.sr.QCD_B_List )

# %%
ttjets_tree = Tree(fc.sr.TTJets)

# %%
trees = [signal_tree,qcd_tree,ttjets_tree]

# %%
study.cutflow(trees,log=1,ratio=1,stacked=1,lumikey=lumikey)

# %%
for tree in trees: print_raw_info(tree)
# Out:
# NMSSM & 0.3 & 484002 & 203326 & 7528.91\\
# QCD\_bEnriched\_HT200to300 & 80430.0 & 18462184 & 9 & 2342.30\\
# QCD\_bEnriched\_HT300to500 & 16620.0 & 11197722 & 913 & 80953.82\\
# QCD\_bEnriched\_HT500to700 & 1487.0 & 9246898 & 5633 & 54115.28\\
# QCD\_bEnriched\_HT700to1000 & 296.5 & 1844165 & 2317 & 22254.41\\
# QCD\_bEnriched\_HT1000to1500 & 46.61 & 1330829 & 2903 & 6073.92\\
# QCD\_bEnriched\_HT1500to2000 & 3.72 & 1431254 & 4224 & 655.87\\
# QCD\_bEnriched\_HT2000toInf & 0.6462 & 401397 & 1240 & 119.26\\
# QCD\_HT200to300\_BGenFilter & 111700.0 & 18762564 & 1 & 355.65\\
# QCD\_HT300to500\_BGenFilter & 27960.0 & 17127050 & 213 & 20773.01\\
# QCD\_HT500to700\_BGenFilter & 3078.0 & 8292039 & 1009 & 22375.03\\
# QCD\_HT700to1000\_BGenFilter & 721.8 & 5952088 & 1791 & 12975.03\\
# QCD\_HT1000to1500\_BGenFilter & 138.2 & 1953159 & 1004 & 4243.94\\
# QCD\_HT1500to2000\_BGenFilter & 13.61 & 511470 & 407 & 646.99\\
# QCD\_HT2000toInf\_BGenFilter & 2.92 & 287303 & 286 & 173.65\\
# TTJets & 831.76 & 340464192 & 429434 & 62674.12\\

# %%
info = dict(log=1,ratio=1,r_ylim=(0.1,1.9),stacked=True,r_grid=True,flip=True,lumikey=lumikey)
study.njets(trees,**info)

# %%
info = dict(log=1,ratio=1,r_ylim=(0.1,1.9),ylim=(1e-1,5e5),stacked=True,r_grid=True,flip=True,lumikey=lumikey)
study.ihiggs(trees,**info)

# %%
info = dict(log=1,ratio=1,r_ylim=(0.1,1.9),ylim=(1e-1,5e5),stacked=True,r_grid=True,flip=True,lumikey=lumikey)
study.ijets(trees,njets=6,**info)
