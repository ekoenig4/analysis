# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
bkgtree = Tree(fc.eightb.preselection.QCD_B_List)

# %%
signaliter = TreeIter([ Tree(fname) for fname in fc.eightb.preselection.signal_list ])

# %%
treeiter = TreeIter([signaliter[-2],bkgtree])

# %%
study.quick(
    signaliter, 
    varlist=[f'{higgs}_m' for higgs in eightb.higgslist+eightb.ylist+['X']],
    dim=(-1,4),
    density=True,
    s_colors=[None]
    # log=True
)

# %%
study.quick(
    treeiter, 
    varlist=[f'{quark}_{var}' for quark in eightb.quarklist for var in ('ptRegressed','eta','phi','btag') ],
    dim=(-1,4),
    density=True
)

# %%
study.quick(
    treeiter, 
    varlist=[f'{quark}_{var}' for quark in eightb.higgslist for var in ('pt','eta','phi','m') ],
    dim=(-1,4),
    density=True
)

# %%
study.quick(
    treeiter, 
    varlist=[f'{quark}_{var}' for quark in eightb.ylist for var in ('pt','eta','phi','m') ],
    dim=(-1,4),
    density=True
)

# %%
study.quick(
    treeiter, 
    varlist=[f'{quark}_{var}' for quark in ['X'] for var in ('pt','eta','phi','m') ],
    dim=(-1,4),
    density=True
)
