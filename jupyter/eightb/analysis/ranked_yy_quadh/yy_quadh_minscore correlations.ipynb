# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
module = fc.eightb.preselection.t8btag_minmass
module
# Out:
# /store/user/ekoenig/8BAnalysis/NTuples/2018/preselection/t8btag_minmass
#    JetHT_Data
#    NMSSM_XYY_YToHH_8b
#    QCD
#    Run2_Autumn18
#    Run2_UL
#    TTJets

# %%
ttbar = ObjIter([Tree(module.Run2_UL18.TTJets)])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.51s/it]

# %%
altfile='yy_quadh_bkg10_soft025_md_allsig_{base}'
# signal = ObjIter([])
# signal = ObjIter([ Tree(f, report=False) for f in tqdm(module.signal_list) ])
signal = ObjIter([ Tree(f, report=False, altfile=altfile) for f in tqdm(module.signal_list) ])

# bkg = ObjIter([])
bkg = ObjIter([ Tree(module.Run2_UL18.QCD_B_List, altfile=altfile), Tree(module.Run2_UL18.TTJets, altfile=altfile)])

data = ObjIter([])
# data = ObjIter([ Tree(module.Run2_UL18.JetHT_Data_UL_List) ])
# Out:
# ...
# 100%|██████████| 1/1 [00:02<00:00,  2.26s/it]

# %%
study.quick2d(
    signal+bkg,
    varlist=['Y1_m','Y2_m'],
    scatter=True,
    legend=True,
    # exe=plot_histo2d_x_corr,
)
# Out:
# 100%|██████████| 1/1 [00:04<00:00,  4.13s/it]

# %%
study.quick(
    signal,
    varlist=['nfound_select'],
    efficiency=True
)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.61s/it]

# %%
study.quick2d(
    signal+bkg,
    varlist=['Y1_m','Y2_m'],
    legend=True,
    # scatter=True,
    # exe=plot_histo2d_x_corr,
)

study.quick2d(
    signal+bkg,
    varlist=['X_m','Y1_m'],
    legend=True,
    # scatter=True,
)
# Out:
# ...
# 100%|██████████| 1/1 [00:03<00:00,  3.81s/it]

# %%
study.quick(
    signal+bkg,
    varlist=['yy_quadh_minscore'],
    efficiency=True
)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.91s/it]

# %%
study.compare_masks(
    signal,bkg,
    masks=[None,lambda t:t.yy_quadh_minscore < 0.5 ,lambda t:t.yy_quadh_minscore < 0.2],
    label=['None','yy_quadh_minscore < 0.5' ,'yy_quadh_minscore < 0.2'],
    varlist=['X_m','Y1_m','H1Y1_m'],
    legend=True,
    # efficiency=True,
    log=True,

    ratio=True, r_inv=True,
)
# Out:
# ...
# 100%|██████████| 3/3 [00:03<00:00,  1.30s/it]

# %%
study.quick2d(
    signal+bkg,
    # masks=lambda t:t.yy_quadh_minscore < 0.5,
    varlist=['H1Y1_m','H2Y1_m'],
    legend=True,
    # scatter=True,
    # exe=plot_histo2d_x_corr,
)

study.quick2d(
    signal+bkg,
    masks=lambda t:t.yy_quadh_minscore < 0.5,
    varlist=['H1Y1_m','H2Y1_m'],
    legend=True,
    # scatter=True,
    # exe=plot_histo2d_x_corr,
)
# Out:
# ...
# 100%|██████████| 1/1 [00:03<00:00,  3.28s/it]

# %%
study.quick2d(
    signal+bkg,
    masks=lambda t:t.yy_quadh_minscore < 0.5,
    varlist=['Y1_m','Y2_m'],
    legend=True,
    # scatter=True,
    # exe=plot_histo2d_x_corr,
)

study.quick2d(
    signal+bkg,
    masks=lambda t:t.yy_quadh_minscore < 0.5,
    varlist=['X_m','Y1_m'],
    legend=True,
    # scatter=True,
)
# Out:
# ...
# 100%|██████████| 1/1 [00:05<00:00,  5.15s/it]

# %%
study.quick2d(
    signal+bkg,
    varlist=['X_m','Y1_m'],
    scatter=True,
)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.98s/it]
