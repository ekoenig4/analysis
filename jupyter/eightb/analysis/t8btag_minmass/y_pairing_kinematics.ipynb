# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
varinfo.clear()

# %%
module = fc.eightb.preselection.t8btag_minmass
dout = 't8btag_minmass'

# %%
signal = ObjIter([ Tree(f) for f in module.signal_list ])
bkg = ObjIter([ Tree(module.QCD_B_List), Tree(module.TTJets)])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# 100%|██████████| 1/1 [00:01<00:00,  1.24s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.06it/s]
# 100%|██████████| 16/16 [00:08<00:00,  1.80it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/analysis/t8btag_minmass/y_pairing_kinematics.ipynb Cell 5' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/analysis/t8btag_minmass/y_pairing_kinematics.ipynb#ch0000004vscode-remote?line=0'>1</a> signal = ObjIter([ Tree(f) for f in module.signal_list ])
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/analysis/t8btag_minmass/y_pairing_kinematics.ipynb#ch0000004vscode-remote?line=1'>2</a> bkg = ObjIter([ Tree(module.QCD_B_List), Tree(module.TTJets)])
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py:195, in Tree.__init__(self, filelist, allow_empty, use_gen, cache)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=190'>191</a> # if not allow_empty:
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=191'>192</a> #     self.filelist = list(filter(lambda fn : fn.raw_events > 0,self.filelist))
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=193'>194</a> init_sample(self)
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=194'>195</a> init_tree(self, use_gen, cache)
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py:132, in init_tree(self, use_gen, cache)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=128'>129</a> self.fields = list(set.intersection(*[ set(fn.fields) for fn in self.filelist]))
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=130'>131</a> if self.lazy :
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=131'>132</a>     self.ttree = ut.lazy([ f'{fn.fname}:sixBtree' for fn in self.filelist ], array_cache=cache)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=132'>133</a> else:
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=133'>134</a>     self.ttree = ut.lazy([fn.tree for fn in self.filelist])
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py:536, in lazy(files, filter_name, filter_typename, filter_branch, recursive, full_paths, step_size, decompression_executor, interpretation_executor, array_cache, library, custom_classes, allow_missing, **options)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=533'>534</a> count = 0
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=534'>535</a> for file_path, object_path in files:
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=535'>536</a>     obj = uproot._util.regularize_object_path(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=536'>537</a>         file_path, object_path, custom_classes, allow_missing, real_options
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=537'>538</a>     )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=539'>540</a>     if obj is not None:
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/behaviors/TBranch.py?line=540'>541</a>         count += 1
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/_util.py:1051, in regularize_object_path(file_path, object_path, custom_classes, allow_missing, options)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/_util.py?line=1048'>1049</a> if allow_missing and object_path not in file:
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/_util.py?line=1049'>1050</a>     return None
# -> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/_util.py?line=1050'>1051</a> return file[object_path]
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py:2106, in ReadOnlyDirectory.__getitem__(self, where)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2102'>2103</a>     return step
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2104'>2105</a> else:
# -> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2105'>2106</a>     return self.key(where).get()
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py:2509, in ReadOnlyKey.get(self)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2505'>2506</a> context = {"breadcrumbs": (), "TKey": self}
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2507'>2508</a> try:
# -> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2508'>2509</a>     out = cls.read(chunk, cursor, context, self._file, selffile, parent)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2510'>2511</a> except uproot.deserialization.DeserializationError:
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/reading.py?line=2511'>2512</a>     breadcrumbs = context.get("breadcrumbs")
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:1296, in DispatchByVersion.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1284'>1285</a>     raise ValueError(
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1285'>1286</a>         """Unknown version {} for class {} that cannot be skipped """
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1286'>1287</a>         """because its number of bytes is unknown.
#    (...)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1290'>1291</a>         )
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1291'>1292</a>     )
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1293'>1294</a> # versioned_cls.read starts with numbytes_version again because move=False (above)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1294'>1295</a> return cls.postprocess(
# -> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1295'>1296</a>     versioned_cls.read(
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1296'>1297</a>         chunk, cursor, context, file, selffile, parent, concrete=concrete
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1297'>1298</a>     ),
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1298'>1299</a>     chunk,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1299'>1300</a>     cursor,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1300'>1301</a>     context,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1301'>1302</a>     file,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1302'>1303</a> )
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:806, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=800'>801</a> if context.get("reading", True):
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=801'>802</a>     self.hook_before_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=802'>803</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=803'>804</a>     )
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=805'>806</a>     self.read_members(chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=807'>808</a>     self.hook_after_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=808'>809</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=809'>810</a>     )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=811'>812</a> self.check_numbytes(chunk, cursor, context)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py:773, in Model_TTree_v20.read_members(self, chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=766'>767</a> self._members["fClusterSize"] = cursor.array(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=767'>768</a>     chunk, self.member("fNClusterRange"), tmp, context
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=768'>769</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=769'>770</a> self._members["fIOFeatures"] = file.class_named("ROOT::TIOFeatures").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=770'>771</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=771'>772</a> )
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=772'>773</a> self._members["fBranches"] = file.class_named("TObjArray").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=773'>774</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=774'>775</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=775'>776</a> self._members["fLeaves"] = file.class_named("TObjArray").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=776'>777</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=777'>778</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=778'>779</a> self._members["fAliases"] = uproot.deserialization.read_object_any(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=779'>780</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TTree.py?line=780'>781</a> )
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:806, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=800'>801</a> if context.get("reading", True):
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=801'>802</a>     self.hook_before_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=802'>803</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=803'>804</a>     )
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=805'>806</a>     self.read_members(chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=807'>808</a>     self.hook_after_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=808'>809</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=809'>810</a>     )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=811'>812</a> self.check_numbytes(chunk, cursor, context)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py:57, in Model_TObjArray.read_members(self, chunk, cursor, context, file)
#      <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=54'>55</a> self._data = []
#      <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=55'>56</a> for _ in range(self._members["fSize"]):
# ---> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=56'>57</a>     item = uproot.deserialization.read_object_any(
#      <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=57'>58</a>         chunk, cursor, context, file, self._file, self._parent
#      <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=58'>59</a>     )
#      <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TObjArray.py?line=59'>60</a>     self._data.append(item)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py:306, in read_object_any(chunk, cursor, context, file, selffile, parent, as_class)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=292'>293</a>         raise DeserializationError(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=293'>294</a>             """invalid class-tag reference: {}
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=294'>295</a>
#    (...)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=301'>302</a>             file.file_path,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=302'>303</a>         )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=304'>305</a>     cls = cursor.refs[ref]  # reference class
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=305'>306</a>     obj = cls.read(chunk, cursor, context, file, selffile, parent)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=307'>308</a> else:
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/deserialization.py?line=308'>309</a>     obj = as_class.read(chunk, cursor, context, file, selffile, parent)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:1296, in DispatchByVersion.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1284'>1285</a>     raise ValueError(
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1285'>1286</a>         """Unknown version {} for class {} that cannot be skipped """
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1286'>1287</a>         """because its number of bytes is unknown.
#    (...)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1290'>1291</a>         )
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1291'>1292</a>     )
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1293'>1294</a> # versioned_cls.read starts with numbytes_version again because move=False (above)
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1294'>1295</a> return cls.postprocess(
# -> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1295'>1296</a>     versioned_cls.read(
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1296'>1297</a>         chunk, cursor, context, file, selffile, parent, concrete=concrete
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1297'>1298</a>     ),
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1298'>1299</a>     chunk,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1299'>1300</a>     cursor,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1300'>1301</a>     context,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1301'>1302</a>     file,
#    <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=1302'>1303</a> )
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:806, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=800'>801</a> if context.get("reading", True):
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=801'>802</a>     self.hook_before_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=802'>803</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=803'>804</a>     )
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=805'>806</a>     self.read_members(chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=807'>808</a>     self.hook_after_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=808'>809</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=809'>810</a>     )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=811'>812</a> self.check_numbytes(chunk, cursor, context)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py:488, in Model_TBranch_v13.read_members(self, chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=475'>476</a> self._members["fIOFeatures"] = file.class_named("ROOT::TIOFeatures").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=476'>477</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=477'>478</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=478'>479</a> (
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=479'>480</a>     self._members["fOffset"],
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=480'>481</a>     self._members["fMaxBaskets"],
#    (...)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=485'>486</a>     self._members["fZipBytes"],
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=486'>487</a> ) = cursor.fields(chunk, _tbranch13_format2, context)
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=487'>488</a> self._members["fBranches"] = file.class_named("TObjArray").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=488'>489</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=489'>490</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=490'>491</a> self._members["fLeaves"] = file.class_named("TObjArray").read(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=491'>492</a>     chunk, cursor, context, file, self._file, self.concrete
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=492'>493</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/models/TBranch.py?line=493'>494</a> self._cursor_baskets = cursor.copy()
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:812, in Model.read(cls, chunk, cursor, context, file, selffile, parent, concrete)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=805'>806</a>     self.read_members(chunk, cursor, context, file)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=807'>808</a>     self.hook_after_read_members(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=808'>809</a>         chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=809'>810</a>     )
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=811'>812</a> self.check_numbytes(chunk, cursor, context)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=813'>814</a> self.hook_before_postprocess(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=814'>815</a>     chunk=chunk, cursor=cursor, context=context, file=file
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=815'>816</a> )
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=817'>818</a> out = self.postprocess(chunk, cursor, context, file)
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:892, in Model.check_numbytes(self, chunk, cursor, context)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=866'>867</a> """
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=867'>868</a> Args:
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=868'>869</a>     chunk (:doc:`uproot.source.chunk.Chunk`): Buffer of contiguous data
#    (...)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=882'>883</a> likely.
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=883'>884</a> """
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=884'>885</a> import uproot.deserialization
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=886'>887</a> uproot.deserialization.numbytes_check(
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=887'>888</a>     chunk,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=888'>889</a>     self._cursor,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=889'>890</a>     cursor,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=890'>891</a>     self._num_bytes,
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=891'>892</a>     self.classname,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=892'>893</a>     context,
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=893'>894</a>     getattr(self._file, "file_path", None),
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=894'>895</a> )
#
# File /uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py:388, in Model.classname(self)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=378'>379</a> @property
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=379'>380</a> def classname(self):
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=380'>381</a>     """
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=381'>382</a>     The C++ (decoded) classname of the modeled class.
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=382'>383</a>
#    (...)
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=385'>386</a>     :doc:`uproot.model.classname_version`.
#     <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=386'>387</a>     """
# --> <a href='file:///uscms_data/d3/ekoenig/mambaforge/envs/py-env/lib/python3.9/site-packages/uproot/model.py?line=387'>388</a>     return classname_decode(self.encoded_classname)[0]
#
# KeyboardInterrupt:

# %%
bkg.reweight(2.3)
bkg.set_systematics(0.2)
# Out:
# [None, None]
