# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
varinfo.clear()

# %%
module = fc.eightb.preselection.ranked_quadh
dout = "ranked_quadh_hybrid"

# %%
signal = ObjIter([ Tree(f) for f in module.signal_list ])
bkg = ObjIter([ Tree(module.QCD_B_List), Tree(module.TTJets)])
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.04s/it]
# 100%|██████████| 1/1 [00:00<00:00,  1.12it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.34s/it]
# 100%|██████████| 16/16 [00:08<00:00,  1.87it/s]
# 100%|██████████| 1/1 [00:00<00:00,  1.17it/s]

# %%
bkg.reweight(2.3)
bkg.set_systematics(0.2)
# Out:
# [None, None]

# %%
(signal+bkg).apply(lambda t : build_collection(t, 'H\dY\d_b\d', 'jet', ordered='pt'))
# Out:
# [None, None, None, None, None]

# %%
# path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models/quadh_ranker/20221026_ranger_lr0.0047_batch128_m10_withbkg"
# path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models/quadh_ranker_opt/20221101_ranger_lr0.0047_batch256_m10_cosphi_withbkg/"
# path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models//quadh_ranker_opt/20221102_ranger_lr0.0047_batch256_m10_cosphi_weighted_mse_withbkg/"
# path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models/quadh_ranker_opt/20221103_ranger_lr0.0047_batch256_m10_cosphi_weighted_mse_withbkg/"
path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models/quadh_ranker_opt/20221108_ranger_lr0.0047_batch256_m10_cosphi_weighted_mse_withbkg/"
# path = f"/uscms_data/d3/ekoenig/8BAnalysis/studies/weaver-multiH/weaver/models/quadh_ranker/20221029_ranger_lr0.0047_batch256_m10_cosphi_withbkg"

# %%
def get_hm_asym(t):
    jet_p4 = build_p4(t, prefix='jet', use_regressed=True)
        
    def build_higgs(jet_p4, jet_index):
        jet_p4 = jet_p4[:, jet_index]
        higgs_p4 = jet_p4[:,:,0] + jet_p4[:,:,1]
        return higgs_p4

    higgs_m = [ build_higgs(jet_p4, jet_index).m for jet_index in eightb.quadh_index.transpose(1,0,2) ]
    hm_asym = sum([ (h1-125)**2/125 for i, h1 in enumerate(higgs_m) ])
    return hm_asym

# %%
def load_quadh(tree, model=None, nasym=50):
  ranker = eightb.load_weaver_output(tree, model, fields=['scores'])

  gnn_score = ranker['scores']
  hm_asym = get_hm_asym(tree)

  mask = ak_rank(hm_asym, axis=-1) < nasym
  
  gnn_score = gnn_score*mask + ak.min(gnn_score,axis=-1)*(~mask)*gnn_score

  rank, argrank = ak.max(gnn_score, axis=-1), ak.argmax( gnn_score, axis=-1 )
  tree.extend(quadh_score=rank)

  quadh_index = ak.from_regular( eightb.quadh_index[argrank] )
  build_all_dijets(tree, pairs=quadh_index, ordered='pt', name='higgs')

# %%
(signal+bkg).apply(lambda t : load_quadh(t, path), report=True)
# (signal).apply(lambda t : eightb.load_quadh(t, path), report=True)
# Out:
# 100%|██████████| 5/5 [02:43<00:00, 32.68s/it]
# [None, None, None, None, None]

# %%
def nfound_higgs(t):
    nhiggs = ak.sum(t.higgs_signalId>-1,axis=-1)
    t.extend(nfound_paired_h=nhiggs)
signal.apply(nfound_higgs)
# Out:
# [None, None, None]

# %%
study.quick( 
    signal+bkg,
    # signal,
    efficiency=True,
    varlist=['quadh_score'],
    binlist=[(0,0.2,30)],

    **study.auroc,
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]

# %%
study.quick(
    signal+bkg,
    # signal,
    legend=True, h_label_stat='$\mu={stats.mean:0.2f}$',
    varlist=[f'higgs_m[:,{i}]' for i in range(4)],
    binlist=[(0,300,30)]*4,
    dim=-1,
    efficiency=True,
    saveas=f'{dout}/higgs_m'
)
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  3.51it/s]

# %%
varinfo.higgs_m = dict(bins=(0,300,30))

# %%
for i in range(4):
    study.quick( 
        signal+bkg, 
        # signal, 
        legend=True, efficiency=True,
        varlist=[f'higgs_{var}[:,{i}]' for var in ('pt','m','eta','phi','dr')],
        dim=-1,
        saveas=f'{ordinal(i)}_pt_higgs'
    )
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.84it/s]
# 100%|██████████| 5/5 [00:01<00:00,  3.97it/s]
# 100%|██████████| 5/5 [00:01<00:00,  3.58it/s]
# 100%|██████████| 5/5 [00:01<00:00,  3.51it/s]

# %%
study.quick(
    signal+bkg, legend=True, h_label_stat='mean',
    efficiency=True,
    varlist=['n_jet'],
    xlabels=['N Jets after Selections'],
    saveas=f'{dout}/n_presel_jets'
)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.57s/it]

# %%
study.quick(
    signal, legend=True, h_label_stat='mean',
    efficiency=True,
    varlist=['nfound_all','nfound_presel','nfound_select'],
    xlabels=['N Higgs Jets','N Higgs Jets in Preselection','N Higgs Jets in Top 8 b-tagged'],
    dim=-1,
    saveas=f'{dout}/n_higgs_jets'
)
# Out:
# 100%|██████████| 3/3 [00:00<00:00,  8.51it/s]

# %%
njets_lost = lambda t:t.nfound_presel-t.nfound_select

def frac_events(t):
    nlost = njets_lost(t)
    return f"{ak.mean(nlost>0):0.2%}"

signal.apply(frac_events)
# Out:
# ['14.56%', '17.56%', '19.26%']

# %%
study.quick(
    signal, legend=True, h_label_stat='mean',
    varlist=[njets_lost],
    xlabels=['N Higgs Jets in Preselection Lost after Top 8 b-tagged'],
    dim=-1,
    efficiency=True,
    saveas=f'{dout}/n_higgs_jets_lost'
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  7.74it/s]

# %%
study.quick(
    bkg+signal, legend=True,
    varlist=['n_loose_btag','n_medium_btag','n_tight_btag'],
    efficiency=True, dim=-1,
    **study.auroc,

    saveas=f'{dout}/btag_multi'
)
# Out:
# 100%|██████████| 3/3 [00:01<00:00,  1.54it/s]

# %%
for i in range(8):
    study.quick( 
        signal+bkg, legend=True, 
        varlist=[f'jet_{var}[:,{i}]' for var in ('ptRegressed','btag','eta','phi')],
        efficiency=True,
        dim=-1,
        saveas=f'{dout}/{ordinal(i)}_pt_jet'
    )
# Out:
# 100%|██████████| 4/4 [00:01<00:00,  2.98it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.93it/s]
# 100%|██████████| 4/4 [00:02<00:00,  1.86it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.91it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.57it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.33it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.42it/s]
# 100%|██████████| 4/4 [00:01<00:00,  2.56it/s]

# %%
varinfo.higgs_m = dict(bins=(0,500,30))
varinfo.higgs_dr = dict(bins=(0,4,30))

# %%
i = 0
study.quick( 
        # signal+bkg, 
        signal, 
        legend=True, efficiency=True,
        # masks=lambda t:np.abs( t.higgs_m[:,i]-125 ) < 30, 
        masks=lambda t:t.higgs_signalId[:,i]!=-1, 
        varlist=[f'higgs_{var}[:,{i}]' for var in ('pt','m','eta','phi','dr','signalId')],
        dim=-1,
    )
# Out:
# 100%|██████████| 6/6 [00:00<00:00,  8.82it/s]

# %%
i = 0
study.compare_masks( 
        # signal+bkg, 
        signal, 
        legend=True, 
        # efficiency=True,
        # masks=lambda t:np.abs( t.higgs_m[:,i]-125 ) < 30, 
        masks=[lambda t:t.higgs_signalId[:,i]!=-1,lambda t:t.higgs_signalId[:,i]==-1], 
        label=['true higgs','fake higgs'],
        varlist=[f'higgs_{var}[:,{i}]' for var in ('pt','m','eta','phi','dr')],
        dim=-1,
    )
# Out:
# 100%|██████████| 5/5 [00:00<00:00, 11.26it/s]
# 100%|██████████| 5/5 [00:00<00:00, 11.52it/s]
# 100%|██████████| 5/5 [00:00<00:00,  9.10it/s]

# %%
for i in range(4):
    study.quick( 
        signal+bkg, 
        # signal, 
        legend=True, efficiency=True,
        varlist=[f'higgs_{var}[:,{i}]' for var in ('pt','m','eta','phi','dr')],
        dim=-1,
        saveas=f'{ordinal(i)}_pt_higgs'
    )
# Out:
# 100%|██████████| 5/5 [00:02<00:00,  1.72it/s]
# 100%|██████████| 5/5 [00:03<00:00,  1.61it/s]
# 100%|██████████| 5/5 [00:03<00:00,  1.39it/s]
# 100%|██████████| 5/5 [00:03<00:00,  1.40it/s]

# %%
# for i in range(2):
#     study.quick( 
#         signal+bkg, legend=True, efficiency=True,
#         varlist=[f'Y{i+1}_{var}' for var in ('pt','m','eta','phi')],
#         dim=-1,
#         saveas=f'{dout}/{ordinal(i)}_pt_y'
#     )

# %%
varinfo.X_m = dict(bins=(500,2000,30))

# %%
study.quick( 
    signal+bkg, legend=True, efficiency=True,
    varlist=[f'X_{var}' for var in ('pt','m','eta','phi')],
    dim=-1,
    saveas=f'{dout}/X'
)
# Out:
# 100%|██████████| 4/4 [00:04<00:00,  1.24s/it]

# %%
study.quick(
    signal+bkg, 
    legend=True,
    h_label_stat='mean',
    # log=True, 
    efficiency=True,
    varlist=['quadh_score'],
    binlist=[(0,0.2,30)],
    # xlabels=['Minimum Higgs Mass Asymmetry'],

    **study.auroc,
    saveas=f'{dout}/quadh_score_roc',
)
# Out:
# 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]

# %%
study.quick(
    signal, legend=True, h_label_stat='mean',
    varlist=['nfound_paired_h'],
    efficiency=True,
    xlabels=['N Reconstructed True Higgs in Selection'],
    saveas=f'{dout}/n_higgs_reco',
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14.39it/s]

# %%
study.quick(
    signal+bkg, legend=True,
    # scale=[100]*len(signal),
    plot_scale=[100]*len(signal),
    varlist=['X_m'],
    limits=True,
    saveas=f'{dout}/limits/no_cuts'
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 100%|██████████| 1/1 [00:23<00:00, 23.80s/it]

# %%
study.quick(
    signal+bkg, legend=True,
    masks=lambda t:t.n_loose_btag==8,
    varlist=['X_m'],
    binlist=[(500,2000,25)],
    limits=True,
    saveas=f'{dout}/limits/n_loose_btag==8'
)
# Out:
# 100%|██████████| 1/1 [00:11<00:00, 11.16s/it]

# %%
loose_btag_mask = lambda t:t.n_loose_btag>=4

# %%
study.quick(
    signal+bkg, 
    masks=loose_btag_mask,
    legend=True,
    # h_label_stat='mean',
    # log=True, 
    efficiency=True,
    varlist=['quadh_score','n_loose_btag','n_medium_btag'],
    binlist=[(0,0.2,30)],
    dim=-1,
    # xlabels=['Minimum Higgs Mass Asymmetry'],
    **study.auroc,
)
# Out:
# 100%|██████████| 3/3 [00:03<00:00,  1.19s/it]

# %%
study.quick2d(
    signal+bkg, 
    masks=loose_btag_mask,
    # h_label_stat='mean',
    # log=True, 
    varlist=['n_medium_btag','quadh_score',],
    binlist=[None,(0,0.2,30)],
    exe=draw_abcd(x_r=(0,4,9), y_r=(0,0.07,0.2))
)
# Out:
# 100%|██████████| 1/1 [00:02<00:00,  2.88s/it]

# %%
bdt = ABCD(
    features=['X_m','X_pt'],
    a = lambda t : loose_btag_mask(t) & (t.n_medium_btag >  4) & (t.quadh_score > 0.07),
    b = lambda t : loose_btag_mask(t) & (t.n_medium_btag <= 4) & (t.quadh_score > 0.07),
    c = lambda t : loose_btag_mask(t) & (t.n_medium_btag >  4) & (t.quadh_score < 0.07),
    d = lambda t : loose_btag_mask(t) & (t.n_medium_btag <= 4) & (t.quadh_score < 0.07),
)

# %%
varinfo.X_m = dict(bins=(500,2000,20))
for r in ('a','b','c','d'):
    study.quick(
        signal + bkg, 
        legend=True,
        # plot_scale=[10]*len(signal),
        masks=getattr(bdt,r),
        varlist=['X_m'],
        limits=True,
        title=f'Region {r.upper()}',
        saveas=f'{dout}/limits/region_{r}'
    )
# Out:
# 100%|██████████| 1/1 [00:18<00:00, 18.40s/it]
# 100%|██████████| 1/1 [00:18<00:00, 18.17s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.59s/it]
# 100%|██████████| 1/1 [00:17<00:00, 17.64s/it]

# %%
bdt.train(bkg)
bdt.print_results(bkg)
# Out:
# --- ABCD Results ---
# k = 2.296e-02
# k*(b/a)-1  = -17.83%
# BDT(b)/a-1 = -29.15%

# %%
study.quick_region(
    bkg, bkg, bkg, label=['target','k factor','bdt'],
    h_color=['black','red','orange'], legend=True,
    masks=[bdt.c]*len(bkg)+[bdt.d]*(len(bkg)*2),
    scale=[1]*len(bkg)+[bdt.scale_tree]*len(bkg)+[bdt.reweight_tree]*len(bkg),
    varlist=bdt.feature_names,
    suptitle='Training (MC-Bkg) D $\\rightarrow$ C',
    ratio=True,
    saveas=f'{dout}/bdt/training'
)
# Out:
# 100%|██████████| 2/2 [00:05<00:00,  2.87s/it]

# %%
study.quick_region(
    bkg, bkg, bkg, label=['target','k factor','bdt'],
    h_color=['black','blue','green'], legend=True,
    masks=[bdt.a]*len(bkg)+[bdt.b]*(len(bkg)*2),
    scale=[1]*len(bkg)+[bdt.scale_tree]*len(bkg)+[bdt.reweight_tree]*len(bkg),
    varlist=bdt.feature_names,
    suptitle='Applying (MC-Bkg) B $\\rightarrow$ A',
    saveas=f'{dout}/bdt/applying',
    ratio=True,
)
# Out:
# 100%|██████████| 2/2 [00:05<00:00,  2.99s/it]

# %%
study.quick(
    signal + bkg, 
    legend=True,
    masks=bdt.a,
    varlist=['X_m'],
    limits=True,
    title='Region A',
    saveas=f'{dout}/limits/region_a'
)
# Out:
# 100%|██████████| 1/1 [00:17<00:00, 17.18s/it]

# %%
study.quick(
    signal + bkg, 
    legend=True,
    masks=[bdt.a]*len(signal)+[bdt.b]*(len(bkg)*2),
    scale=[1]*len(signal)+[bdt.reweight_tree]*len(bkg),
    varlist=['X_m'],
    title='BDT Bkg Model',
    limits=True,
    saveas=f'{dout}/limits/bdt_bkg_model'
)
# Out:
# 100%|██████████| 1/1 [00:16<00:00, 16.69s/it]
