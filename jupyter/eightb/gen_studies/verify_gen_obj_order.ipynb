# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
fn = "/uscms_data/d3/ekoenig/8BAnalysis/analysis/CMSSW_10_2_18/src/sixB/analysis/sixBanalysis/NMSSM_XYY_YToHH_8b_MX_700_MY_300_accstudies.root"
tree = Tree(fn)

# %%
hist2d_simple(tree.gen_Y1_pt,tree.gen_Y2_pt)
y_order = np.all(tree.gen_Y1_pt >= tree.gen_Y2_pt)
print("Y1 pt > Y2 pt:",y_order)
# Out:
# Y1 pt > Y2 pt: True

# %%
hist2d_simple(tree.gen_H1Y1_pt,tree.gen_H2Y1_pt)
y1_h_order = np.all(tree.gen_H1Y1_pt >= tree.gen_H2Y1_pt)
print("H1Y1 pt > H2Y1 pt:",y1_h_order)
# Out:
# H1Y1 pt > H2Y1 pt: True

# %%
hist2d_simple(tree.gen_H1Y2_pt,tree.gen_H2Y2_pt)
y2_h_order = np.all(tree.gen_H1Y2_pt >= tree.gen_H2Y2_pt)
print("H1Y2 pt > H2Y2 pt:",y2_h_order)
# Out:
# H1Y2 pt > H2Y2 pt: True

# %%
hist2d_simple(tree.gen_H1Y1_b1_pt,tree.gen_H1Y1_b2_pt)
h1y1_b_order = np.all(tree.gen_H1Y1_b1_pt >= tree.gen_H1Y1_b2_pt)
print("H1Y1 b1 pt > H1Y1 b2 pt:",h1y1_b_order)
# Out:
# H1Y1 b1 pt > H1Y1 b2 pt: True

# %%
hist2d_simple(tree.gen_H2Y1_b1_pt,tree.gen_H2Y1_b2_pt)
H2y1_b_order = np.all(tree.gen_H2Y1_b1_pt >= tree.gen_H2Y1_b2_pt)
print("H2Y1 b1 pt > H2Y1 b2 pt:",H2y1_b_order)
# Out:
# H2Y1 b1 pt > H2Y1 b2 pt: True

# %%
hist2d_simple(tree.gen_H1Y2_b1_pt,tree.gen_H1Y2_b2_pt)
h1Y2_b_order = np.all(tree.gen_H1Y2_b1_pt >= tree.gen_H1Y2_b2_pt)
print("H1Y2 b1 pt > H1Y2 b2 pt:",h1Y2_b_order)
# Out:
# H1Y2 b1 pt > H1Y2 b2 pt: True

# %%
hist2d_simple(tree.gen_H2Y2_b1_pt,tree.gen_H2Y2_b2_pt)
H2Y2_b_order = np.all(tree.gen_H2Y2_b1_pt >= tree.gen_H2Y2_b2_pt)
print("H2Y2 b1 pt > H2Y2 b2 pt:",H2Y2_b_order)
# Out:
# H2Y2 b1 pt > H2Y2 b2 pt: True
