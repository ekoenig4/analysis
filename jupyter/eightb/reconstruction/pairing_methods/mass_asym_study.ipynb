# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
qcd = ObjIter([Tree(fc.eightb.preselection.QCD_B_List)])

# %%
varinfo.clear()

# %%
(qcd).apply(lambda t:build_collection(t, 'H\dY\d_b\d', 'jet', ptordered=True))
# Out:
# [None]

# %%
study.quick(
  qcd,
  varlist=[ f'jet_{var}[:,{i}]' for i in range(8) for var in ('pt','m','eta','phi') ],
  dim=(-1,4),
)
# Out:
#   0%|          | 0/32 [00:00<?, ?it/s]OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.
# 100%|██████████| 32/32 [00:12<00:00,  2.58it/s]

# %%
quad_index = combinations(8, [4, 4])
def pair_x_y(t):
  jets = get_collection(t, f'jet', False)

  def _y(jets):
    jp4 = [ build_p4(jets[:,i], use_regressed=True) for i in range(4) ]
    yp4 = jp4[0] + jp4[1] + jp4[2] + jp4[3]
    return ak.zip({ var:getattr(yp4,var) for var in ('pt','m','eta','phi') })
  ys = ak_stack([ 
    ak_stack([_y(jets[:,comb[0]]), _y(jets[:,comb[1]])])
    for comb in quad_index 
  ])
  ys = reorder_collection(ys, ak.argsort(-ys.pt, axis=-1))
  y1, y2 = ys[:,:,0], ys[:,:,1]

  yorder = ak.argsort(-(y1.pt+y2.pt),axis=-1)

  t.extend( rename_collection(y1[yorder], f'y1'), rename_collection(y2[yorder], f'y2') )
(qcd).apply(pair_x_y)
# Out:
# [None]

# %%
qcd.y1_m
# Out:
# [<Array [[159, 234, ... 2.24e+03, 2.23e+03]] type='111157 * var * float32'>]

# %%
study.quick2d(
  qcd,
  varlist=['y1_m','y2_m'],
  binlist=[(0,1000,30)]*2
  )
# Out:
# 100%|██████████| 1/1 [00:27<00:00, 27.97s/it]

# %%
ysort
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb Cell 10' in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000026vscode-remote?line=0'>1</a> ysort
#
# NameError: name 'ysort' is not defined

# %%
pair_index = combinations(4, [2,2])
def pair_y_higgs(t, y='Y1'):
  jets = get_collection(t, f'{y}_jet', False)

  def _higgs(jets):
    jp4 = [ build_p4(jets[:,i], use_regressed=True) for i in range(2) ]
    hp4 = jp4[0] + jp4[1]
    return ak.zip({ var:getattr(hp4,var) for var in ('pt','m','eta','phi') })
  higgs = ak_stack([ 
    ak_stack([_higgs(jets[:,comb[0]]), _higgs(jets[:,comb[1]])])
    for comb in pair_index 
  ])
  higgs = reorder_collection(higgs, ak.argsort(-higgs.pt, axis=-1))
  h1, h2 = higgs[:,:,0], higgs[:,:,1]
  t.extend( rename_collection(h1, f'{y}_h1'), rename_collection(h2, f'{y}_h2') )

(qcd).apply(pair_y_higgs)
(qcd).apply(lambda t:pair_y_higgs(t, y='Y2'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb Cell 6' in <module>
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=13'>14</a>   h1, h2 = higgs[:,:,0], higgs[:,:,1]
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=14'>15</a>   t.extend( rename_collection(h1, f'{y}_h1'), rename_collection(h2, f'{y}_h2') )
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=16'>17</a> (qcd).apply(pair_y_higgs)
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=17'>18</a> (qcd).apply(lambda t:pair_y_higgs(t, y='Y2'))
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py:111, in ObjIter.apply(self, obj_function, report)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=107'>108</a> def apply(self,obj_function, report=False):
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=108'>109</a>     it = tqdm(self) if report else self
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=110'>111</a>     out = ObjIter([ obj_function(obj) for obj in it ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=111'>112</a>     return out
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py:111, in <listcomp>(.0)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=107'>108</a> def apply(self,obj_function, report=False):
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=108'>109</a>     it = tqdm(self) if report else self
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=110'>111</a>     out = ObjIter([ obj_function(obj) for obj in it ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/ObjIter.py?line=111'>112</a>     return out
#
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb Cell 6' in pair_y_higgs(t, y)
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=6'>7</a>   hp4 = jp4[0] + jp4[1]
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=7'>8</a>   return ak.zip({ var:getattr(hp4,var) for var in ('pt','m','eta','phi') })
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=8'>9</a> higgs = ak_stack([
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=9'>10</a>   ak_stack([_higgs(jets[:,comb[0]]), _higgs(jets[:,comb[1]])])
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=10'>11</a>   for comb in pair_index
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=11'>12</a> ])
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=12'>13</a> higgs = reorder_collection(higgs, ak.argsort(-higgs.pt, axis=-1))
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=13'>14</a> h1, h2 = higgs[:,:,0], higgs[:,:,1]
#
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb Cell 6' in <listcomp>(.0)
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=6'>7</a>   hp4 = jp4[0] + jp4[1]
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=7'>8</a>   return ak.zip({ var:getattr(hp4,var) for var in ('pt','m','eta','phi') })
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=8'>9</a> higgs = ak_stack([
# ---> <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=9'>10</a>   ak_stack([_higgs(jets[:,comb[0]]), _higgs(jets[:,comb[1]])])
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=10'>11</a>   for comb in pair_index
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=11'>12</a> ])
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=12'>13</a> higgs = reorder_collection(higgs, ak.argsort(-higgs.pt, axis=-1))
#      <a href='vscode-notebook-cell://ssh-remote%2Bfnalgpu1/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/pairing_methods/mass_asym_study.ipynb#ch0000015vscode-remote?line=13'>14</a> h1, h2 = higgs[:,:,0], higgs[:,:,1]
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py:997, in Array.__getitem__(self, where)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=584'>585</a> """
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=585'>586</a> Args:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=586'>587</a>     where (many types supported; see below): Index of positions to
#    (...)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=993'>994</a> have the same dimension as the array being indexed.
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=994'>995</a> """
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=995'>996</a> if not hasattr(self, "_tracers"):
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=996'>997</a>     tmp = ak._util.wrap(self.layout[where], self._behavior)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=997'>998</a> else:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=998'>999</a>     tmp = ak._connect._jax.jax_utils._jaxtracers_getitem(self, where)
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py:284, in PartitionedArray.__getitem__(self, where)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=278'>279</a> elif isinstance(head, slice):
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=279'>280</a>     partitions = self._ext.getitem_range(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=280'>281</a>         head.start, head.stop, head.step
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=281'>282</a>     ).partitions
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=282'>283</a>     return IrregularlyPartitionedArray(
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=283'>284</a>         [x[(slice(None),) + tail] for x in partitions]
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=284'>285</a>     )
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=286'>287</a> elif head is Ellipsis:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=287'>288</a>     return IrregularlyPartitionedArray(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=288'>289</a>         [x[(head,) + tail] for x in self.partitions]
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=289'>290</a>     )
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py:284, in <listcomp>(.0)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=278'>279</a> elif isinstance(head, slice):
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=279'>280</a>     partitions = self._ext.getitem_range(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=280'>281</a>         head.start, head.stop, head.step
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=281'>282</a>     ).partitions
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=282'>283</a>     return IrregularlyPartitionedArray(
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=283'>284</a>         [x[(slice(None),) + tail] for x in partitions]
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=284'>285</a>     )
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=286'>287</a> elif head is Ellipsis:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=287'>288</a>     return IrregularlyPartitionedArray(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=288'>289</a>         [x[(head,) + tail] for x in self.partitions]
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=289'>290</a>     )
#
# ValueError: in NumpyArray, too many dimensions in slice
#
# (https://github.com/scikit-hep/awkward-1.0/blob/1.7.0/src/libawkward/array/NumpyArray.cpp#L4680)
