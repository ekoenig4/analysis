# %%
# %load_ext autoreload
# %autoreload 2

import os
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import torch

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

import utils.torchUtils as gnn

# %%
bkgtrees = ObjIter([Tree(fc.eightb.preselection.QCD_B_List)])

# %%
# signaltrees = ObjIter([Tree(fc.eightb.preselection.signal_list[i]) for i in (0,4,7)])
signaltrees = ObjIter([Tree(fc.eightb.preselection.signal_list[i]) for i in (0,4,7)])

# %%
for tree in signaltrees: tree.color=None

# %%
gnn.config.set_gpu(False)

# %%
model_paths = [
    # "/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/models/golden_pair/lightning_logs/version_2/checkpoints/epoch=20-step=7538.ckpt",
    "/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/models/golden_pair/lightning_logs/version_3/checkpoints/epoch=21-step=7897.ckpt"
]

# %%
model = gnn.modelMap['golden_pair'].load_from_checkpoint(model_paths[-1]).to(device=gnn.config.device)

# %%
from torch_geometric.data import Data

class predict_data(gnn.BaseTransform):
    def __init__(self, model=model):
        super().__init__()
        self.model = model
    def __call__(self, data : Data) -> Data:
        pairs = torch.LongTensor([ [i,j] for i in range(data.num_nodes) for j in range(i+1, data.num_nodes)])
        def predict_pair(data, pair):
            data = gnn.sample_pair(data, pair)
            return model.predict(data)
        edge_o = torch.Tensor([predict_pair(data, pair) for pair in pairs])
        min_o, max_o = edge_o.min(), edge_o.max()
        data.edge_o = (edge_o-min_o)/(max_o+min_o)
        data.rank_o = data.edge_o.argsort(descending=True).argsort()
        return data

# %%
transform = gnn.Transform()
transform.append(gnn.min_edge_neighbor(n_neighbor=model.hparams['n_neighbor'], undirected=True))
template = gnn.Dataset("../data/template",make_template=True, transform=transform)

# %%
def get_tree_graph(tree, ver='testing', path='../data'):
    sample = tree.sample
    dataset = gnn.Dataset(f'{path}/{sample}-{ver}', transform=template.transform+predict_data(model)+gnn.to_uptri_graph())
    loader = gnn.DataLoader(dataset, batch_size=50, num_workers=gnn.config.ncpu)
    tree.graphs = loader

def get_qcd_graph(tree, path='../data'):
    get_name = lambda f : f.fname.split('/')[-2]
    dataset = gnn.concat_dataset([f'{path}/{sample}' for sample in map(get_name, tree.filelist)],transform=template.transform+predict_data(model)+gnn.to_uptri_graph())
    loader = gnn.DataLoader(dataset, batch_size=50, num_workers=gnn.config.ncpu)
    tree.graphs = loader

# %%
signaltrees.apply(get_tree_graph)
bkgtrees.apply(get_qcd_graph)
# Out:
# [None]

# %%
tree = signaltrees[-1]

# %%
build_all_dijets(tree)

# %%
def predict_dataset(dataset):
    score = []
    for i,batch in enumerate(dataset):
        score.append(batch.edge_o)
    score = torch.cat(score).cpu().numpy()
    return score

def predict_tree(tree):
    score = predict_dataset(tree.graphs)
    n_dijets = ak.count(tree.dijet_pt, axis=-1)
    score = ak.unflatten(score, n_dijets)
    tree.extend(dijet_score=score)

# %%
predict_tree(tree)

# %%
study.quick(
    [tree, tree],
    masks=[lambda t: (t.nfound_presel==8)&(t.dijet_signalId>-1), lambda t:(t.nfound_presel==8)&(t.dijet_signalId==-1)],
    varlist=['dijet_score'],
     density=True,
)

# %%
study.quick(
    [tree],
    masks=lambda t:ak.argmax(tree.dijet_score,axis=-1),
    varlist=['dijet_signalId','dijet_m'],
    density=True,
)

# %%
select_higgs(signaltrees[0], 'score', nhiggs=4)

# %%
study.quick(
    [tree],
    varlist=[lambda t:ak.sum(t.dijet_signalId>-1, axis=-1),
    lambda t:ak.sum(t.gnn_higgs_signalId>-1, axis=-1),
    lambda t:ak.sum(t.dijet_signalId>-1, axis=-1)-ak.sum(t.gnn_higgs_signalId>-1, axis=-1)],
    dim=(-1,3), 
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb Cell 19' in <module>
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=0'>1</a> study.quick(
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=1'>2</a>     [tree],
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=2'>3</a>     varlist=[lambda t:ak.sum(t.dijet_signalId>-1, axis=-1),
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=3'>4</a>     lambda t:ak.sum(t.gnn_higgs_signalId>-1, axis=-1),
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=4'>5</a>     lambda t:ak.sum(t.dijet_signalId>-1, axis=-1)-ak.sum(t.gnn_higgs_signalId>-1, axis=-1)],
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=5'>6</a>     dim=(-1,3),
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=6'>7</a> )
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py:147, in quick(varlist, binlist, xlabels, dim, size, flip, figax, *args, **kwargs)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=143'>144</a>     continue
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=145'>146</a> bins, xlabel = study.format_var(var, bins, xlabel)
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=146'>147</a> hists = study.get(var)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=147'>148</a> weights = study.get_scale(hists)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=148'>149</a> hist_multi(hists, bins=bins, xlabel=xlabel,
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=149'>150</a>            weights=weights, **study.attrs, figax=(fig, ax))
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py:94, in Study.get(self, key)
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=91'>92</a>     if ie is not None: item = item[:,int(ie)]
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=92'>93</a>     return item
# ---> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=93'>94</a> items = [_get_item(selection,key) for selection in self.selections]
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=94'>95</a> if self.masks is not None:
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=95'>96</a>     items = _mask_items(self, items)
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py:94, in <listcomp>(.0)
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=91'>92</a>     if ie is not None: item = item[:,int(ie)]
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=92'>93</a>     return item
# ---> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=93'>94</a> items = [_get_item(selection,key) for selection in self.selections]
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=94'>95</a> if self.masks is not None:
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=95'>96</a>     items = _mask_items(self, items)
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py:89, in Study.get.<locals>._get_item(selection, key, ie)
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=87'>88</a> def _get_item(selection,key, ie=None):
# ---> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=88'>89</a>     if callable(key): return key(selection)
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=89'>90</a>     if ":" in key: key,ie = key.split(":")
#      <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Study.py?line=90'>91</a>     item = selection[key]
#
# /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb Cell 19' in <lambda>(t)
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=0'>1</a> study.quick(
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=1'>2</a>     [tree],
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=2'>3</a>     varlist=[lambda t:ak.sum(t.dijet_signalId>-1, axis=-1),
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=3'>4</a>     lambda t:ak.sum(t.gnn_higgs_signalId>-1, axis=-1),
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=4'>5</a>     lambda t:ak.sum(t.dijet_signalId>-1, axis=-1)-ak.sum(t.gnn_higgs_signalId>-1, axis=-1)],
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=5'>6</a>     dim=(-1,3),
#       <a href='vscode-notebook-cell://ssh-remote%2Bfnal/uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/jupyter/eightb/graph_net/label-trick-gnn/check-golden.ipynb#ch0000017vscode-remote?line=6'>7</a> )
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py:124, in Tree.__getattr__(self, key)
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=123'>124</a> def __getattr__(self, key): return self[key]
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py:118, in Tree.__getitem__(self, key)
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/classUtils/Tree.py?line=117'>118</a> def __getitem__(self, key): return self.ttree[key]
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py:997, in Array.__getitem__(self, where)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=584'>585</a> """
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=585'>586</a> Args:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=586'>587</a>     where (many types supported; see below): Index of positions to
#    (...)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=993'>994</a> have the same dimension as the array being indexed.
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=994'>995</a> """
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=995'>996</a> if not hasattr(self, "_tracers"):
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=996'>997</a>     tmp = ak._util.wrap(self.layout[where], self._behavior)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=997'>998</a> else:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/highlevel.py?line=998'>999</a>     tmp = ak._connect._jax.jax_utils._jaxtracers_getitem(self, where)
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py:243, in PartitionedArray.__getitem__(self, where)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=235'>236</a>     return PartitionedArray.from_ext(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=236'>237</a>         self._ext.getitem_range(where.start, where.stop, where.step)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=237'>238</a>     )
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=239'>240</a> elif isinstance(where, str) or (
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=240'>241</a>     ak._util.py27 and isinstance(where, ak._util.unicode)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=241'>242</a> ):
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=242'>243</a>     return self.replace_partitions([x[where] for x in self.partitions])
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=244'>245</a> elif isinstance(where, tuple) and len(where) == 0:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=245'>246</a>     return self
#
# File ~/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py:243, in <listcomp>(.0)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=235'>236</a>     return PartitionedArray.from_ext(
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=236'>237</a>         self._ext.getitem_range(where.start, where.stop, where.step)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=237'>238</a>     )
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=239'>240</a> elif isinstance(where, str) or (
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=240'>241</a>     ak._util.py27 and isinstance(where, ak._util.unicode)
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=241'>242</a> ):
# --> <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=242'>243</a>     return self.replace_partitions([x[where] for x in self.partitions])
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=244'>245</a> elif isinstance(where, tuple) and len(where) == 0:
#     <a href='file:///uscms/home/ekoenig/nobackup/miniconda3/envs/torch-gpu/lib/python3.8/site-packages/awkward/partition.py?line=245'>246</a>     return self
#
# ValueError: key "gnn_higgs_signalId" does not exist (not in record)
#
# (https://github.com/scikit-hep/awkward-1.0/blob/1.7.0/src/libawkward/util.cpp#L525)
