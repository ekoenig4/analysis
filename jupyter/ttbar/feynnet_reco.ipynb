# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
module = fc.ttbar.preselection.Run2_UL18
module
# Out:
# /store/user/ekoenig/TTAnalysis/NTuples/2018/preselection/Run2_UL/RunIISummer20UL18NanoAODv9
#    QCD
#    TTJets

# %%
def use_file(f):
    return f.replace('ntuple_0.root', 'ntuple_1.root')
ttbar = ObjIter([Tree( [use_file(f) for f in module.TTToHadronic] )])
# qcd = ObjIter([Tree(module.Run2_UL18.QCD_B_List)])

def use_file(f):
    return f.replace('ntuple.root', 'ntuple_1.root')
qcd = ObjIter([Tree([ use_file(f) for f in module.QCD_B_List ] )])
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  2.01it/s]
# 100%|██████████| 16/16 [00:05<00:00,  2.87it/s]

# %%
ttbar[0].is_signal = True

# %%
def reconstruct_ttbar(jet_p4, comb):
    b_p4  = jet_p4[comb[:,::3]]
    wj1 = jet_p4[comb[:,1::3]]
    wj2 = jet_p4[comb[:,2::3]]
    w_p4 = wj1 + wj2
    t_p4 = b_p4 + w_p4

    return dict(
        **{
            f't_{field}':getattr(t_p4,field)
            for field in ('pt','m','eta','phi')
        },
        **{
            f'W_{field}':getattr(w_p4,field)
            for field in ('pt','m','eta','phi')
        },
        **{
            f'W_j1_{field}':getattr(wj1,field)
            for field in ('pt','m','eta','phi','btag','signalId')
        },
        **{
            f'W_j2_{field}':getattr(wj2,field)
            for field in ('pt','m','eta','phi','btag','signalId')
        },
        **{
            f'b_{field}':getattr(b_p4,field)
            for field in ('pt','m','eta','phi','btag','signalId')
        },
    )

# %%
import utils.ttbarUtils.models as ttbar_models


def load_ranker_reco(t, model):
    ranker = eightb.load_weaver_output(t, model=model, fields=['maxcomb','maxscore'])


    jet_p4 = build_p4(t, prefix='jet', extra=['btag','signalId'])
    combs = ak.from_regular( ranker['maxcomb'].astype(int) )
    t.extend(
        **reconstruct_ttbar(jet_p4, combs)
    )

# %%
(ttbar + qcd).apply(lambda t : load_ranker_reco(t, model=ttbar_models.feynnet_bool_btag.path))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 (ttbar + qcd).apply(lambda t : load_ranker_reco(t, model=ttbar_models.feynnet_bool_btag.path))
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py:149, in ObjIter.apply(self, obj_function, report, parallel)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=145'>146</a>     return self._parallel_apply(obj_function, jobs=parallel)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=147'>148</a> it = tqdm(self) if report else self
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=148'>149</a> out = ObjIter([ obj_function(obj) for obj in it ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=150'>151</a> return out
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py:149, in <listcomp>(.0)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=145'>146</a>     return self._parallel_apply(obj_function, jobs=parallel)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=147'>148</a> it = tqdm(self) if report else self
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=148'>149</a> out = ObjIter([ obj_function(obj) for obj in it ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/classUtils/ObjIter.py?line=150'>151</a> return out
#
# Cell In [8], line 1, in <lambda>(t)
# ----> 1 (ttbar + qcd).apply(lambda t : load_ranker_reco(t, model=ttbar_models.feynnet_bool_btag.path))
#
# Cell In [7], line 5, in load_ranker_reco(t, model)
#       4 def load_ranker_reco(t, model):
# ----> 5     ranker = eightb.load_weaver_output(t, model=model, fields=['maxcomb','maxscore'])
#       8     jet_p4 = build_p4(t, prefix='jet', extra=['btag','signalId'])
#       9     combs = ak.from_regular( ranker['maxcomb'].astype(int) )
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py:200, in load_weaver_output(tree, model, fields)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=196'>197</a> rgxs = [ os.path.basename(os.path.dirname(fn.fname))+"_"+os.path.basename(fn.fname)+".awkd" for fn in tree.filelist ]
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=197'>198</a> toload = [ fn for rgx in rgxs for fn in glob.glob( os.path.join(model,"predict_output",rgx) ) ]
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=199'>200</a> fields = {
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=200'>201</a>   field:np.concatenate([ np.array(ak0.load(fn)[field], dtype=float) for fn in toload ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=201'>202</a>   for field in fields
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=202'>203</a> }
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=203'>204</a> return fields
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py:201, in <dictcomp>(.0)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=196'>197</a> rgxs = [ os.path.basename(os.path.dirname(fn.fname))+"_"+os.path.basename(fn.fname)+".awkd" for fn in tree.filelist ]
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=197'>198</a> toload = [ fn for rgx in rgxs for fn in glob.glob( os.path.join(model,"predict_output",rgx) ) ]
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=199'>200</a> fields = {
# --> <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=200'>201</a>   field:np.concatenate([ np.array(ak0.load(fn)[field], dtype=float) for fn in toload ])
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=201'>202</a>   for field in fields
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=202'>203</a> }
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/eightbStudies/utils/eightbUtils/pairing.py?line=203'>204</a> return fields
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: need at least one array to concatenate

# %%
study.quick(
    ttbar+qcd,
    legend=True,
    h_fit='gaussian',h_fit_peak=True,
    h_label_stat='{fit.mu:0.2f}',
    varlist=['t_m','W_m'],
    binlist=[(0,500,30),(0,200,30)],
    efficiency=True,
)
# Out:
# 100%|██████████| 2/2 [00:32<00:00, 16.15s/it]

# %%
study.quick(
    ttbar,
    varlist=['nfound_select'],
    efficiency=True,
)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.81s/it]

# %%
study.quick(
    ttbar,
    masks=lambda t : t.nfound_select==6,
    legend=True,
    h_fit='gaussian',h_fit_peak=True,
    h_label_stat='{fit.mu:0.2f}',
    varlist=['t_m','W_m'],
    binlist=[(0,500,30),(0,200,30)],
    efficiency=True,
)
# Out:
# 100%|██████████| 2/2 [00:01<00:00,  1.34it/s]

# %%
def get_reco_id(t):

    b_id = t.b_signalId
    w1_id = t.W_j1_signalId
    w2_id = t.W_j2_signalId
    b_id = ak.where( ((b_id+3) % 3) == 0, b_id//3, -1 )
    w_id = ak.where( (w1_id//3) == (w2_id//3), w1_id//3, -1 )
    t_id = ak.where( b_id == w_id, b_id, -1)
    reco_id = 1* ak.all(t_id > -1, axis=1)

    t.extend(
        reco_id = 1*(ak.all(t_id > -1, axis=1))
    )
ttbar.apply(get_reco_id)
# Out:
# [None]

# %%
study.quick(
    ttbar,
    masks=lambda t : t.nfound_select==6,
    varlist=['reco_id'],
    efficiency=True,
    
    legend=True,
    h_label_stat=lambda h:f'{h.histo[-1]:0.2f}',
)
# Out:
# 100%|██████████| 1/1 [00:03<00:00,  3.18s/it]

# %%
sixj_ttbar = ttbar.apply(EventFilter('six_jets', filter=lambda t:t.nfound_select==6))

# %%
def btag_multi(t):
    t.extend(
        n_loose_btag = ak.sum( t.jet_btag>jet_btagWP[1], axis=1),
        n_medium_btag = ak.sum( t.jet_btag>jet_btagWP[2], axis=1),
        n_tight_btag = ak.sum( t.jet_btag>jet_btagWP[3], axis=1),
    )
sixj_ttbar.apply(btag_multi)
# Out:
# [None]

# %%
sixj_ttbar.apply(lambda t: t.n_loose_btag==2).apply(ak.mean)
# Out:
# [0.4006383175731201]

# %%
study.quick(
    sixj_ttbar,
    masks=lambda t: t.n_loose_btag==2,
    varlist=['reco_id'],
    efficiency=True,
    
    legend=True,
    h_label_stat=lambda h:f'{h.histo[-1]:0.2%}',
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14.43it/s]

# %%
study.quick(
    sixj_ttbar,
    masks=lambda t: t.n_medium_btag==2,
    varlist=['reco_id'],
    efficiency=True,
    
    legend=True,
    h_label_stat=lambda h:f'{h.histo[-1]:0.2%}',
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 12.50it/s]

# %%
study.quick(
    sixj_ttbar,
    masks=lambda t: t.n_tight_btag==2,
    varlist=['reco_id'],
    efficiency=True,
    
    legend=True,
    h_label_stat=lambda h:f'{h.histo[-1]:0.2%}',
)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 14.90it/s]
