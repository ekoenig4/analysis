# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
bkg_arrays =  [ np.random.exponential(125, size=100000), np.random.exponential(125, size=10000) ]
bkg_weights = [ np.random.normal(1, 0.1, size=100000), np.random.normal(1, 0.1, size=10000) ]

# %%
stack = Stack.from_arrays(bkg_arrays, bins=(0,500,30), weights=bkg_weights, efficiency=True, label=['qcd','ttbar'], color=['blue','green'])

# %%
plot_stack(stack, legend=True)
# Out:
# (<Figure size 650x650 with 1 Axes>, <AxesSubplot:ylabel='Events'>)

# %%
import pickle

# %%
with open('stack.pkl', 'wb') as f:
    pickle.dump(stack, f)

# %%
with open('stack.pkl', 'rb') as f:
    stack = pickle.load(f)

# %%
plot_stack(stack, legend=True)
# Out:
# (<Figure size 650x650 with 1 Axes>, <AxesSubplot:ylabel='Events'>)

# %%
sig_array = np.random.normal(200, 50, 1000)
# Out:
# (<Figure size 650x650 with 1 Axes>, <AxesSubplot:>)
