# %%
# %load_ext autoreload
# %autoreload 2

import os
os.environ['KMP_WARNINGS'] = 'off'
import sys
import git

import uproot as ut
import awkward as ak
import numpy as np
import math
import vector
import sympy as sp

import re
from tqdm import tqdm
import timeit
import re

sys.path.append( git.Repo('.', search_parent_directories=True).working_tree_dir )
from utils import *

# %%
# %load_ext line_profiler
# %load_ext memory_profiler

# %%
module = fc.eightb.preselection.t8btag_minmass

# %%
# signal = ObjIter([Tree(module.NMSSM_XYY_YToHH_8b_MX_1000_MY_450)])
bkg = ObjIter([Tree(module.Run2_UL18.QCD_B_List)])
# Out:
# 100%|██████████| 16/16 [00:07<00:00,  2.22it/s]

# %%
study.h_quick( 
    bkg,
    legend=True,
    log=True,
    varlist=['n_mu'],
    exe=draw_cut(x=1, selection='<'),
)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 study.h_quick(
#       2     bkg,
#       3     h_label_stat='{stats.cut_eff:0.2%}',
#       4     legend=True,
#       5     log=True,
#       6     varlist=['n_mu'],
#       7     exe=draw_cut(x=1, selection='<'),
#       8 )
#
# File /uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py:234, in h_quick(varlist, binlist, xlabels, dim, size, flip, figax, *args, **kwargs)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=231'>232</a>     bins, xlabel = format_var(var, bins, xlabel)
#     <a href='file:///uscms_data/d3/ekoenig/8BAnalysis/studies/sixbStudies/utils/studyUtils/studyUtils.py?line=232'>233</a>     counts, bins, error = study.get_histogram(var)
# ...

# %%
signal.cutflow.apply(lambda cs : [ c.histo.shape for c in cs ])
# Out:
# [[(7,)]]

# %%
bkg.cutflow.apply(lambda cs : [ c.histo.shape for c in cs ])
# Out:
# [[(8,)], [(10,)], [(7,)], [(7,)], [(7,)], [(7,)], [(7,)], [(7,)], [(8,)], [(7,)], [(7,)], [(7,)], [(7,)], [(7,)], [(7,)], [(7,)]]

# %%
study.cutflow(  
    signal+bkg
)
